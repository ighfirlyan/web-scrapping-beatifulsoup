# %%
#import semua yang kita butuhkan
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen, Request
from mysql_database import MySqlDB
import pandas as pd

# %%
#siapkan semua parameter
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36"
headers = {
    'User-Agent': user_agent
}

alamat = "https://www.kompas.com/"

# %%
#request- response
data_request = Request(alamat, headers=headers)
response = urlopen(data_request)

# %%
#masukkan dalam objek beautifulsoup
soup = bs(response, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PT7PC4');</script>
# <!-- End Google Tag Manager -->
# <title>Berita Terkini Hari Ini, Kabar Akurat Terpercaya - Kompas.com</title>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//asset.kompas.com" rel="dns-prefetch"/>
# <link href="//adsimg.kompas.com" rel="dns-prefetch"/>
# <link href="//static.criteo.net" rel="dns-prefetch"/>
# <link href="//bidder.criteo.com" rel="dns-prefetch"/>
# <link href="//rtax.criteo.com" rel="dns-prefetch"/>
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
# ...

# %%
#div, sidebar-terpopuler 
articles_populer = soup.find("div", {"class":"most__wrap clearfix"})

# %%
titles = articles_populer.find_all("h4", {"class":"most__title"})

# %%
list_title = [title.get_text().rstrip() for title in titles]

# %%
print(list_title)
# Out:
# ['Rusia: Fase Pertama Operasi Militer di Ukraina Tuntas, Giliran Fokus Bebaskan Donbas', 'Rekap Hasil Swiss Open 2022: 5 Wakil Indonesia ke Semifinal, Potensi 2 Duel Merah Putih di Final', 'Target Penonton Langsung Formula E Menyusut, dari 50.000 Jadi 10.000', 'Potret Sirkuit Formula E di Lokasi Berlumpur Sebelum dan Sesudah Dilakukan Pembangunan', '66 Siswa Jatuh dari Jembatan Saat Menunggu Difoto dengan Drone, Kades: Jika 1 Orang Beratnya 50 Kg, Sudah 3 Ton', 'Link Live Streaming Argentina Vs Venezuela, Kickoff 06.30 WIB', 'Pengumuman! Pendaftaran Sayembara Bangunan IKN Nusantara Dibuka Mulai 28 Maret', 'Kisah Pak Guru Ribut, Jelaskan soal Kaum Sodom ke Murid SD, Videonya Viral dan Dipanggil Dinas', 'Klasemen Liga 1: Bali United Juara, Persebaya ke Zona Piala AFC', 'Warga yang Belum Vaksinasi Booster Masih Boleh Mudik Lebaran, Asalkan…']

# %%
#menyimpan dalam sql
db = MySqlDB()
db.open_connection()
db.insert_titles(list_title)
# Out:
# Koneksi Berhasil
#
#                 INSERT INTO ARTIKEL (title)
#                 VALUES ("Rusia: Fase Pertama Operasi Militer di Ukraina Tuntas, Giliran Fokus Bebaskan Donbas")
#
#
#                 INSERT INTO ARTIKEL (title)
#                 VALUES ("Rekap Hasil Swiss Open 2022: 5 Wakil Indonesia ke Semifinal, Potensi 2 Duel Merah Putih di Final")
#
#
#                 INSERT INTO ARTIKEL (title)
#                 VALUES ("Target Penonton Langsung Formula E Menyusut, dari 50.000 Jadi 10.000")
#
#
#                 INSERT INTO ARTIKEL (title)
#                 VALUES ("Potret Sirkuit Formula E di Lokasi Berlumpur Sebelum dan Sesudah Dilakukan Pembangunan")
#
#
#                 INSERT INTO ARTIKEL (title)
#                 VALUES ("66 Siswa Jatuh dari Jembatan Saat Menunggu Difoto dengan Drone, Kades: Jika 1 Orang Beratnya 50 Kg, Sudah 3 Ton")
#
#
#                 INSERT INTO ARTIKEL (title)
# ...

# %%
#melihat data
db.search_all()
# Out:
# (1, 'Kunjungan Kerja Presiden RI ke Provinsi Bali')
# (2, 'Presiden Jokowi Lanjutkan Kunjungan Kerja ke Kabupaten Belu')
# (3, 'Dari Kota Kupang, Presiden Jokowi Bertolak Menuju Kabupaten Timor Tengah Selatan')
# (4, 'Presiden Joko Widodo Resmikan Penataan Kawasan Kota Kupang')
# (5, 'Bertolak ke NTT, Presiden Akan Tinjau Program Percepatan Penurunan Stunting')
# (6, 'Rusia: Fase Pertama Operasi Militer di Ukraina Tuntas, Giliran Fokus Bebaskan Donbas')
# (7, 'Rekap Hasil Swiss Open 2022: 5 Wakil Indonesia ke Semifinal, Potensi 2 Duel Merah Putih di Final')
# (8, 'Target Penonton Langsung Formula E Menyusut, dari 50.000 Jadi 10.000')
# (9, 'Potret Sirkuit Formula E di Lokasi Berlumpur Sebelum dan Sesudah Dilakukan Pembangunan')
# (10, '66 Siswa Jatuh dari Jembatan Saat Menunggu Difoto dengan Drone, Kades: Jika 1 Orang Beratnya 50 Kg, Sudah 3 Ton')
# (11, 'Link Live Streaming Argentina Vs Venezuela, Kickoff 06.30 WIB')
# ...

# %%
#tutup koneksi
db.close_connection()

# %%
df = pd.DataFrame(list_title, columns=['Judul Berita Populer'])

# %%
df
# Out:
#                                 Judul Berita Populer
# 0  Rusia: Fase Pertama Operasi Militer di Ukraina...
# 1  Rekap Hasil Swiss Open 2022: 5 Wakil Indonesia...
# 2  Target Penonton Langsung Formula E Menyusut, d...
# 3  Potret Sirkuit Formula E di Lokasi Berlumpur S...
# 4  66 Siswa Jatuh dari Jembatan Saat Menunggu Dif...
# 5  Link Live Streaming Argentina Vs Venezuela, Ki...
# 6  Pengumuman! Pendaftaran Sayembara Bangunan IKN...
# 7  Kisah Pak Guru Ribut, Jelaskan soal Kaum Sodom...
# 8  Klasemen Liga 1: Bali United Juara, Persebaya ...
# 9  Warga yang Belum Vaksinasi Booster Masih Boleh...

# %%
df.to_csv("scrape_kompas.csv", index=False)
